# %%
# Напишите функцию, которая будет принимать на вход длину стороны квадрата и
# выводить на экран площадь квадрата и его периметр.
def square_perimeter(side: float):
    print(f'Периметр квадрата со стороной {side} равен {side*4}')
    print(f'Площадь квадрата со стороной {side} равен {side*side}')


# Напишите функцию, которая будет принимать два числа и считать сумму
# квадратов этих двух чисел, запишите своё вычисление в переменную squared .
def sum_square(a: float, b: float):
    return a**2 + b**2


# Напишите функцию, которая будет принимать на вход список
# [“male“,“male“,“female“,“male“,“male“,“female“,”female“] и
#возвращать его в обратном порядке. Запишите список в переменную new_list.
def reverse_list(arr: list):
    return arr[::-1]


# Напишите функцию, которая будет принимать на вход список из
# предыдущего задания(new_list) и выводить на экран количество мужчин
# или количество женщин в зависимости от требований пользователя.
#Подсказка: вам необходимо добавить еще один параметр в описание функции
def number_gend(arr: list, req: str):
    return sum([1 for gend in arr if gend == req])

# Напишите функцию, которая будет принимать строку (Например: “female”),
# а возвращать словарь где ключи — это символы строки, а значения кол-во
# символов в строке.
def counter_char(text: str):
    res = {}
    for ch in text:
        if ch == ' ':
            continue
        if ch in res:
            res[ch] += 1
        else:
            res[ch] = 1

    return res

# %%
print('Test for task 1 #########')
square_perimeter(5.)
print('Test for task 2 #########')
a = 3.0
b = 4.
squared = sum_square(a, b)
print(f'Сумма квадратов чисел {a} и {b} равна ', squared)
print('Test for task 3 #########')
arr = ['male','male','female','male','male','female','female']
new_list = reverse_list(arr)
print(new_list)
print('Test for task 4 #########')
print(f"{number_gend(new_list, 'female')} female in list {new_list}")
print(f"{number_gend(new_list, 'male')} male in list {new_list}")
print('Test for task 5 #########')
text = 'female male'
print(f"Частота символов в тексте '{text}': {counter_char(text)}")
# Out:
# Test for task 1 #########
# Периметр квадрата со стороной 5.0 равен 20.0
# Площадь квадрата со стороной 5.0 равен 25.0
# Test for task 2 #########
# Сумма квадратов чисел 3.0 и 4.0 равна  25.0
# Test for task 3 #########
# ['female', 'female', 'male', 'male', 'female', 'male', 'male']
# Test for task 4 #########
# 3 female in list ['female', 'female', 'male', 'male', 'female', 'male', 'male']
# 4 male in list ['female', 'female', 'male', 'male', 'female', 'male', 'male']
# Test for task 5 #########
# Частота символов в тексте 'female male': {'f': 1, 'e': 3, 'm': 2, 'a': 2, 'l': 2}
